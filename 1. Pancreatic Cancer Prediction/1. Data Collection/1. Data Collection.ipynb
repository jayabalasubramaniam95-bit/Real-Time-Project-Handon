# %%
import pandas as pd

# %%
# ---------------- Load Data ----------------
dataset = pd.read_csv("Pancreatic_Cancer.csv")
dataset
# Out:
#       Patient_ID  Demographic_1  Demographic_2  Demographic_3  Demographic_4  \
# 0       PC000001          12.95           6.03          26.04           2.90
# 1       PC000002           0.01           6.05           4.06          14.54
# 2       PC000003          29.01          22.26          13.04          20.73
# 3       PC000004          27.51          39.30          13.71          33.29
# 4       PC000005          32.80          38.72          17.98          10.75
# ...          ...            ...            ...            ...            ...
# 59995   PC059996          96.41         125.47           8.79          45.86
# 59996   PC059997         112.86          79.98          26.03          42.83
# 59997   PC059998          92.03         116.48          42.54          26.40
# 59998   PC059999          14.27          38.09          23.87         122.81
# 59999   PC060000          61.63          12.01          51.17          36.22
#
# ...
